# %%
import os
HOME = os.getcwd()

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ##Using Your Own Dataset:
# If you have your own dataset, compress it into a .zip file and upload it to your Google Drive.
# ###Dataset format
# Accident \
# |--images\
# ---|---taining\
# ---|---validation\
# |--labels\
# ---|---training\
# ---|---validation
#
# Remember : In each file there should be same data both image and labeled data, every image has to be labled with it's class in .txt format
#
#
# ##Using the Provided Sample Dataset:
# If you do not have a dataset, you can download our sample dataset from the following link:
# https://drive.google.com/file/d/12gw_WPnWrmo17kHacBnJQfek72GT0Ac1/view?usp=drive_link
# Once downloaded, upload the .zip file to your Google Drive for further use.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %% [markdown]
# Unzip the file in which you have your training data

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/<selec-the-dataset-zipset>

# %% [markdown]
# Model Selection
# Begin by selecting the desired YOLO model (e.g., yolov8n.pt, yolov5s.pt) and ensure it is downloaded or available in your working directory.
#
# ##Dataset Configuration
# Create a new file named data.yaml in your project directory. This file should follow the standard YOLO format: .yaml
#
# save this file at Location: datasets\filename\data.yaml
#
# ##Training
# Train the model for 100 epochs using the provided configuration. After training, the best-performing model will be saved automatically at:
#
# runs/detect/train/weights/best.pt
#
# ##Model Deployment
# Use the best.pt model in your Python inference script to detect anomalies in video streams or images.

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=<model-name> data=/content/datasets/<zipfile-foldername>/data.yaml epochs=100 imgsz=640 plots=True
